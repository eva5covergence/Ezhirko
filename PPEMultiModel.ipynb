# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
import glob
import torch
import os
import PIL

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
os.chdir("/content/drive/MyDrive/EVA5_Capstone/PPEMultiModel/")

# %% [markdown]
# # Training yolo branch only by freezing the midas layers on 64x64 resolution
# The weights from assignment 14 is taken to pre initialize the weights of yolo layers. MIDAS pretrained weights assigned to Midas layers. The encoder and decoder of midas layer is freezed and only yolo layers are trained now.

# %%
# !python train.py --data data/customdata/custom.data --batch 32  --cache --cfg cfg/yolov3-custom.cfg --epochs 200 --weights 'weights/last_ppe.pt'  --img-size=64 --midasnet_freeze='True'
# Out:
# Namespace(accumulate=4, adam=False, batch_size=32, bbox_lambda=1, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', depth_lambda=1, device='', epochs=200, evolve=False, img_size=[64], init_train='False', midas_weights='', midasnet_freeze='True', multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/best.pt', yolo_freeze='False', yolo_weights='')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-11-20 22:23:05.067187: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# cfg - cfg/yolov3-custom.cfg
# data - data/customdata/custom.data
# epochs - 200
# batch_size - 32
# accumulate - 4
# yolo weights -
# midas weights -
# imgsz_min- 64, imgsz_max- 64, imgsz_test- 64
# opt.rect - False
# ...

# %% [markdown]
# The best weights from previous trainning on 64x64 is taken to pre initialize the weights of yolo layers. MIDAS pretrained weights assigned to Midas layers. The encoder and decoder of midas layer is freezed and only yolo layers are trained now on 128x128

# %%
## Ignore the model summary in the below output - as it is summary on dummy input (3, 416,416) and before freezing the midas layers. But you can observe img_size attribute though as 128.
# Training yolo branch only by freezing the midas layers on 128x128 resolution
# !python train.py --data data/customdata/custom.data --batch 16  --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --weights 'weights/best.pt'  --img-size=128 --midasnet_freeze='True'
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bbox_lambda=1, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', depth_lambda=1, device='', epochs=300, evolve=False, img_size=[128], init_train='False', midas_weights='', midasnet_freeze='True', multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/best.pt', yolo_freeze='False', yolo_weights='')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-11-21 04:10:25.884063: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# cfg - cfg/yolov3-custom.cfg
# data - data/customdata/custom.data
# epochs - 300
# batch_size - 16
# accumulate - 4
# yolo weights -
# midas weights -
# imgsz_min- 128, imgsz_max- 128, imgsz_test- 128
# ...

# %% [markdown]
# The best weights from previous trainning on 128x128 is taken to pre initialize the weights of yolo layers. MIDAS pretrained weights assigned to Midas layers. The encoder and decoder of midas layer is freezed and only yolo layers are trained now on 256x256

# %%
# !python train.py --data data/customdata/custom.data --batch 8  --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --weights 'weights/best.pt'  --img-size=256 --midasnet_freeze='True'
# Out:
# Namespace(accumulate=4, adam=False, batch_size=8, bbox_lambda=1, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', depth_lambda=1, device='', epochs=300, evolve=False, img_size=[256], init_train='False', midas_weights='', midasnet_freeze='True', multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/best.pt', yolo_freeze='False', yolo_weights='')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-11-21 10:16:38.185608: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# cfg - cfg/yolov3-custom.cfg
# data - data/customdata/custom.data
# epochs - 300
# batch_size - 8
# accumulate - 4
# yolo weights -
# midas weights -
# imgsz_min- 256, imgsz_max- 256, imgsz_test- 256
# ...

# %% [markdown]
# The best weights from previous trainning on 256x256 is taken to pre initialize the weights of yolo layers. MIDAS pretrained weights assigned to Midas layers. The encoder and decoder of midas layer is freezed and only yolo layers are trained now on 448x448

# %%
# !python train.py --data data/customdata/custom.data --batch 8  --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --weights 'weights/best.pt'  --img-size=448 --midasnet_freeze='True'
# Out:
# Namespace(accumulate=4, adam=False, batch_size=8, bbox_lambda=1, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', depth_lambda=1, device='', epochs=300, evolve=False, img_size=[448], init_train='False', midas_weights='', midasnet_freeze='True', multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/best.pt', yolo_freeze='False', yolo_weights='')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16130MB)
#
# 2020-11-21 16:02:25.412769: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# cfg - cfg/yolov3-custom.cfg
# data - data/customdata/custom.data
# epochs - 300
# batch_size - 8
# accumulate - 4
# yolo weights -
# midas weights -
# imgsz_min- 448, imgsz_max- 448, imgsz_test- 448
# ...

# %% [markdown]
# Disabled Other augmentation which was specific to yolo and tried to train both yolo and midas network with previously trained best weights

# %%
# !python train.py --data data/customdata/custom.data --batch 8  --cache --cfg cfg/yolov3-custom.cfg --epochs 20 --weights 'weights/best.pt'  --img-size=448 --midasnet_freeze='False' --yolo_freeze='False'
# Out:
# Namespace(accumulate=4, adam=False, batch_size=8, bbox_lambda=1, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', depth_lambda=1, device='', epochs=700, evolve=False, img_size=[448], init_train='False', midas_weights='', midasnet_freeze='False', multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/best.pt', yolo_freeze='False', yolo_weights='')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-11-22 14:00:13.722153: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# cfg - cfg/yolov3-custom.cfg
# data - data/customdata/custom.data
# epochs - 700
# batch_size - 8
# accumulate - 4
# yolo weights -
# midas weights -
# imgsz_min- 448, imgsz_max- 448, imgsz_test- 448
# ...

# %%
# !python detect.py --source './test_inputs' --conf-thres 0.1 --yolo_output './yolo_outs/' --depth_output './depth_outs/'
# Out:
# python3: can't open file 'detect.py': [Errno 2] No such file or directory

# %%
from run import run

# %%
input_path = "/content/drive/MyDrive/EVA5_Capstone/PPEMultiModel/data/customdata/inputs/TestImage/"
out_path = "/content/drive/MyDrive/EVA5_Capstone/PPEMultiModel/depth_outs/"
model_path = "/content/drive/MyDrive/EVA5_Capstone/PPEMultiModel/weights/best.pt"

# %%
run(input_path=input_path, output_path=out_path, model_path=model_path)
# Out:
# initialize
# device: cuda
# Downloading: "https://github.com/facebookresearch/WSL-Images/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://download.pytorch.org/models/ig_resnext101_32x8-c38310e5.pth" to /root/.cache/torch/hub/checkpoints/ig_resnext101_32x8-c38310e5.pth
# ...
# Loaded Model weights successfully
# start processing
#   processing /content/drive/MyDrive/EVA5_Capstone/PPEMultiModel/data/customdata/inputs/TestImage/test1.jpg (1/1)
# finished
