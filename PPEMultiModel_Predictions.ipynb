# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
import glob
import torch
import os
import PIL

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', major=7, minor=0, total_memory=16130MB, multi_processor_count=80)

# %%
os.chdir("/content/drive/MyDrive/EVA5_Capstone/PPEMultiModel/")

# %%
# !python detect.py --source './data/customdata/inputs/TestImage/' --conf-thres 0.1 --iou-thres 0.6 --yolo_output './yolo_outs/' --depth_output './depth_outs/' --weights='weights/best.pt'
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, depth_output='./depth_outs/', device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, midas_weights='weights/model-f46da743.pt', names='data/customdata/custom.names', planes_output='planes_output', save_txt=False, source='./data/customdata/inputs/TestImage/', view_img=False, weights='weights/best.pt', yolo_output='./yolo_outs/')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16130MB)
#
# device: cuda:0
# Downloading: "https://github.com/facebookresearch/WSL-Images/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://download.pytorch.org/models/ig_resnext101_32x8-c38310e5.pth" to /root/.cache/torch/hub/checkpoints/ig_resnext101_32x8-c38310e5.pth
# 100% 340M/340M [00:03<00:00, 89.8MB/s]
# Loaded Model weights successfully
# **** Writing BBOX outs ****
# ...

# %%
Image(filename='yolo_outs/TestImage_1.jpg', width=600)

# %%
Image(filename='depth_outs/TestImage_1.png', width=600)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
